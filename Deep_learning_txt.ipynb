# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat1911996sharma/Machine-Learning-Model-Life-Cycle/blob/Regresion-Models/Deep_learning_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#What is Deep Learning ?
'''
Geoffrey Hinton made Deep LEarning (father of it).
Mimic the human brain 

'''

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##The Neuron

# %% [markdown]
# ##How can we mimic the human brain ?
# Because human brain is one of the most poewrful learning tool in the world. If we recreate it, we will have something.
#
# How does a neuron looks like ?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Neurons by themselves are useless . But when you bring them together then it works properly.
# Dendrites is the receiver for the neuron and Axon are the transmitter for the neuron.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Breaking down neuron into machines:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##The Activation Function
# 3rd step values
#
# the 4 most predominant values for the funstions are :
# 1. Threshold function
# 2. Sigmoid Function
# 3. Rectifier Function
# 4. Hyperbolic Tangent (tanh)
#
# If variables are binary then we will use
# 1. Thershold Function (because it is (0,1))
# 2. Sigmoid Function used as a prob. of y being yes or no

# %% [markdown]
# How do NN work ?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We get extra power with hidden layers.
#
# Some weights have non-zero value asnd some have zero value.
#
# for simplicity we remove the zero lines.
#
# In some cities in this example, the neurons in hidden layer three find out that bedrooms were also an important parameter.
#
# then in 4th neuron age is important maybe its for historic properties.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This will prdict price.

# %% [markdown]
# How do NN learn ?
#
# We are dealing with one row.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We get our nn to perform the calculation compare the result against the actual value and re-adjust weights and then recalculate.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This was one epoch
#
# Goal is to minimize the cost function
# This is back propagation.
