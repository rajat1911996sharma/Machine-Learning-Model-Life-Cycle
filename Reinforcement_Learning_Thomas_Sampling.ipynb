# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat1911996sharma/Machine-Learning-Model-Life-Cycle/blob/main/Reinforcement_Learning_Thomas_Sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Thomas Sampling

# %% [markdown]
# Initail State
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There have been some trial rounds and a distribution have been made for the each machine based on sampling.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Very Important Note
# These are not the distribution of the machines but waht we think where the actual distributions might lie.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The likelihood of where the actual machine lies but the not the machine distribution itself.
#
# We are trying to mathematically explain what we think is going on.
#
# ###Thomson Sampling is probablistic
#
# ###UCB is determinitic

# %% [markdown]
# the algorithm will go and pull out a value in each distribution.
#
# By doing that we have generated our own bandit configuration.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We have created an upsido world or our own virtual world.
#
# We pick the machine with highest expected return out of the three in this reality.
#
# Now, we will translate the value to the actual world.
#
# It will then pull the lever and the for the value selected before we get a value that is closer to the distribution because this new value shows the machine distribution.
#
# ![image.png](data:image/png;base64,...)
#
# Now, the lever has been pulled we will adjust our predictions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# This information is new to the algorithm.
# Now, we have to adjust our perception of the world.

# %% [markdown]
# The previous distributions where our prior dsistributions and we have a new value.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# It is easy to see that the distribution got narrower.
#
# We will start a new round now.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, we are gonna pull the lever on the yellow bandit.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, we will adjust the values on our perception
#
# and the distribution gets adjusted
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# New round,
# we will do the same
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# after the maximum expected value is chosen we get the perception of real world.
#
#
# we keep doing until we get
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Importing Dataset

# %%
df = pd.read_csv('Ads_CTR_Optimisation.csv')

# %% [markdown]
# ##Implementing Thomas Sampling

# %%
import random
N = 10000
d = 10
ads_selected = []
#Initilalising the step 1 variables
number_of_rewards_1 = [0] * d
number_of_rewards_0 = [0] * d
total_reward = 0
for n in range(0, N):
  ad = 0
  #similar to UCB we initialize the variable in step 3
  max_random = 0
  for i in range (0, d):
    #step 2
    #random_beta = np.random.beta(number_of_rewards_1[i]+1,number_of_rewards_0[i]+1)
    random_beta = random.betavariate(number_of_rewards_1[i] + 1,number_of_rewards_0[i] + 1)
    if (random_beta > max_random):
      max_random = random_beta
      ad = i
  ads_selected.append(ad)
  reward = df.values[n, ad]
  if reward == 1:
    number_of_rewards_1[ad] = number_of_rewards_1[ad] + 1
  else:
    number_of_rewards_0[ad] = number_of_rewards_1[ad] + 1
  total_reward = total_reward + reward

# %%
import random
N = 10000
d = 10
ads_selected = []
numbers_of_rewards_1 = [0] * d
numbers_of_rewards_0 = [0] * d
total_reward = 0
for n in range(0, N):
  ad = 0
  max_random = 0
  for i in range(0, d):
    random_beta = random.betavariate(numbers_of_rewards_1[i] + 1, numbers_of_rewards_0[i] + 1)
    if (random_beta > max_random):
      max_random = random_beta
      ad = i
  ads_selected.append(ad)
  reward = df.values[n, ad]
  if reward == 1:
    numbers_of_rewards_1[ad] = numbers_of_rewards_1[ad] + 1
  else:
    numbers_of_rewards_0[ad] = numbers_of_rewards_0[ad] + 1
  total_reward = total_reward + reward

# %% [markdown]
# ##Visualizing the results -  Histogram

# %%
plt.hist(ads_selected)
plt.title('Histogram of ads selected')
plt.xlabel('Ads')
plt.ylabel('Number of times each ad was selected')
# Out:
# Text(0, 0.5, 'Number of times each ad was selected')
