# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat1911996sharma/Machine-Learning-Model-Life-Cycle/blob/Regresion-Models/Convolutional_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Convolutinal Neural Networks

# %% [markdown]
# Our Brain sees features. (Duck or the Rabbit puzzle).
# E.g. Tagging People in Social Media, recognizing signs, self- driving cars.
#
# Yann Lecun is the grandfather of Convolutional Neural Networks.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 0 - White
#
# 1 - Black
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Yann Lecun's work](https://wiki.tum.de/display/lfdv/Convolutional+Neural+Network+Architectures#:~:text=In%201990%27s%20Yann%20LeCun%20developed%20first%20application%20Convolutional,for%20Convolutional%20Neural%20Networks.In%20his%20paper%20he%20states)

# %% [markdown]
# #Step 1 Convolution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Simple formula of mathematics basically multiplication of two function.

# %% [markdown]
# [Additional Reading](https://www.semanticscholar.org/paper/Introduction-to-Convolutional-Neural-Networks-Wu/450ca19932fcef1ca6d0442cbf52fec38fb9d1e5)

# %% [markdown]
# Feature Detector can be called as Kernel/filter.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We multiply each value.
#
# Feature Map is called an activation map or convolved map.
#
# The values on feature map preserve features. Features are what our mind perceives.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Step 1(B) ReLU Layer

# %% [markdown]
# We wnat to use relu layer in order to add non-linearity to our model.
#
# It is because images are highly non-linear so we need to break the linearity.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Further Reading](https://arxiv.org/pdf/1609.04112v2.pdf)

# %% [markdown]
# [Further Reading](https://www.cv-foundation.org/openaccess/content_iccv_2015/papers/He_Delving_Deep_into_ICCV_2015_paper.pdf)

# %% [markdown]
# #Step 2 - Pooling

# %% [markdown]
# **Max Pooling**
#
# Why do we need pooling ?
#
# we want our NN to recognize all the different images even if they are different perspectives.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We choose a box and choose a max value in that box.
#
# We are able to preserve the features. But by pooling the features which are the impotant thing we are looking out for.
#
# We get distorted image but reducing the size and parameter. It is good way to prevent overfitting.

# %% [markdown]
# [Further Reading](http://www.ais.uni-bonn.de/papers/icann2010_maxpool.pdf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [A fun example](https://www.cs.ryerson.ca/~aharley/vis/conv/flat.html)

# %% [markdown]
# #Step 3 Flattening

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Step 4 (Full Connection)

# %% [markdown]
# We will add a whole new ANN on back of that.
#
# Hidden Layer in this ANN is called fully connedted layer
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# An appriximate exmaple is classifying a dog or a cat
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Further Reading](https://adeshpande3.github.io/adeshpande3.github.io/The-9-Deep-Learning-Papers-You-Need-To-Know-About.html)
