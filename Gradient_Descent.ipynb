# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat1911996sharma/Machine-Learning-Model-Life-Cycle/blob/Regresion-Models/Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gradient Descent

# %% [markdown]
# First, we try out 1000 values on the back propagatiion on our cost function.
#
# We get:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Best value is the global minima.

# %% [markdown]
# ##Curse of Dimensionality
# Lets suppose we have a neural network with 25 weights
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If we try to brute force our way to the solution of minimization of cost function.
#
# We get:
#
# 10^75 cominations we have to compute to get the correct value.
#
# Now, the worlds fastest computer **Sunway TaihuLight** computes at 93*10^15 or 98 PFLOPS
#
# In an ideal world, it can calculate the value without training first.
#
# We get:
# 10^75 / (93*10^25)
# is approx. equal to
# 1.08*10^58 seconds
# which is
# 3.42*10^50 years
#
# So, Brute Force isnt going to cut it.

# %% [markdown]
# if the NN looks like this:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We apply **Gradient Descent**

# %% [markdown]
# This is our cost function:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lets say we start at here:
#
# From this point, we are going to look at the angle of cost function.
#
# We diffrentiate and find out what the slope is
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The ball rolls around and get to this point by going downhill.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We again calculate the slope and do the same thing.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We repeat the step yet again to go downhill.
# and we reach our global minima.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The traversed path is:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Instead of brute forcing this is way better.

# %% [markdown]
# Gradient Descent in 2D:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Gradient Descent in 3D:
# ![image.png](data:image/png;base64,...)
#
# When we apply this to 2D:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Stocahstic Gradient Descent
# **Gradient Descent** requires the Cost Function to be **convex**. (it has one global minma)
#
# If our cost function is not convex,
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We will find a local minima rather than the global one.
# Like This:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Stochastic on the other hand have no requirement for convex function.

# %% [markdown]
# Gradient Descent method or Batch Gradient Descent method takes all the neurons and calclutes all the rows.
# Then, it adjusts the weight.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In stocahstic Gradient Descent method, we calculate row by row with a neuron and then adjust the weights after every row computation.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Comparing the Gradient Descent vs Stochastic Gradient Descent Method:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Therefore after constant evaluation we get global minimum rather than local minimum in stochastic gradient descent method.
#
# SGD is much more lile;y to find global minmum and is faster.
#
# There is a mini batch Gradient Descent between these two.

# %% [markdown]
# Additional Reading
#
# [A neural Netwerk in 13 lines of Python](https://iamtrask.github.io/2015/07/27/python-network-part2/)
#
# [Neural Network and Deep Learning](https://neuralnetworksanddeeplearning.com/chap2.html)
