# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat1911996sharma/Machine-Learning-Model-Life-Cycle/blob/Regresion-Models/Convolutional_Neural_Network(Implementation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Softmax & Cross-Entropy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How will the NN know that the total values add upto 1.
#
# This is why we use a softmax function.
#
# It is a generalisation of logistic function which squahses the values in between (0,1).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Softmax function comes hand in hand with cross entropy function.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We used mse as a cost function to optimize our network performance.
#
# After using softmax, instead of mse, cross-entropy is a better option.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# NN1 was outperformimg NN2 at all stages.

# %% [markdown]
# What errors we can get to detect type of errors ?
#
# Classification Error: shows that both got one wrong so they are performing similarly.
#
# mse: shows that NN1 has lower error rate than NN2
#
# Cross-Entropy shows same as mse.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When we start our back propagation method, we get large errors which mse cant properly detect.
#
# It converges faster with cross-entropy.
#
# Tip: Geoffery Linton videos

# %% [markdown]
# [More reading](https://rdipietro.github.io/friendly-intro-to-cross-entropy-loss/)

# %% [markdown]
# [great reading](https://peterroelants.github.io/)
